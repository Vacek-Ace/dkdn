# %%
import pandas as pd
import os 
from src.utils import df_description

# %%
df_description(df_path='../data', exp_path='../results/errors')
# Out:
#                 instances n_features class_prop
# a9a                 32561        124      0.241
# appendicitis          106          8      0.198
# australian            690         15      0.445
# backache              180         32      0.139
# banknote             1372          5      0.445
# breastcancer          569         31      0.373
# bupa                  345          6       0.49
# cleve                 303         14      0.455
# cod-rna             59535          9      0.333
# colon-cancer           62       2001      0.355
# diabetes              768          9      0.349
# flare                1066         11      0.171
# fourclass             862          3      0.356
# german_numer         1000         25        0.3
# haberman              306          4      0.265
# heart                 270         14      0.444
# housevotes84          232         17      0.466
# ilpd                  579         11      0.285
# ionosphere            351         35      0.359
# ...
