# %%
import pandas as pd
import os 
from src.utils import df_description

# %%
df_description(df_path='../data', exp_path='../results/errors')
# Out:
#                 instances n_features class_prop
# a9a                 32561        123      0.241
# appendicitis          106          7      0.198
# australian            690         14      0.445
# backache              180         31      0.139
# banknote             1372          4      0.445
# breastcancer          569         30      0.373
# bupa                  345          5       0.49
# cleve                 303         13      0.455
# cod-rna             59535          8      0.333
# colon-cancer           62       2000      0.355
# diabetes              768          8      0.349
# flare                1066         10      0.171
# fourclass             862          2      0.356
# german_numer         1000         24        0.3
# haberman              306          3      0.265
# heart                 270         13      0.444
# housevotes84          232         16      0.466
# ilpd                  579         10      0.285
# ionosphere            351         34      0.359
# ...
