# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import json
import os 
import seaborn as sns
import matplotlib.pyplot as plt
from src.visualization.plots import box_plot_retraining
from src.utils import summary_retraining

# %%
summary = summary_retraining(path='../results/incremental/conf1')

# %%
summary
# Out:
#     dataset                   model proportion performance gap    sample
# 0       a9a                     SVC        0.5       -0.005627  0.590794
# 1       a9a    KNeighborsClassifier        0.5        0.004518  0.590794
# 2       a9a  RandomForestClassifier        0.5        0.002832  0.490825
# 3       a9a                     SVC        0.4       -0.006962  0.590756
# 4       a9a    KNeighborsClassifier        0.4        0.001102  0.630797
# ..      ...                     ...        ...             ...       ...
# 550     w8a    KNeighborsClassifier        0.2        0.034085  0.199704
# 551     w8a  RandomForestClassifier        0.2        0.031072  0.139702
# 552     w8a                     SVC        0.1        0.030923  0.179703
# 553     w8a    KNeighborsClassifier        0.1        0.031866  0.209704
# 554     w8a  RandomForestClassifier        0.1        0.047318  0.129702
#
# [555 rows x 5 columns]

# %%
summary.groupby(['model', 'proportion'])['sample'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.379115
#                         0.2           0.386016
#                         0.3           0.379885
#                         0.4           0.376652
#                         0.5           0.362211
# RandomForestClassifier  0.1           0.263648
#                         0.2           0.247965
#                         0.3           0.256791
#                         0.4           0.253325
#                         0.5           0.268101
# SVC                     0.1           0.306157
#                         0.2           0.300488
#                         0.3           0.290579
#                         0.4           0.287184
#                         0.5           0.297991
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.013829
#                         0.2           0.009787
#                         0.3           0.008145
#                         0.4           0.006495
#                         0.5           0.006146
# RandomForestClassifier  0.1           0.024628
#                         0.2           0.035036
#                         0.3           0.040252
#                         0.4           0.036395
#                         0.5           0.028242
# SVC                     0.1           0.035228
#                         0.2           0.033635
#                         0.3           0.020188
#                         0.4           0.020637
#                         0.5           0.019578
# Name: performance gap, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['sample'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.329421
#                         0.2           0.336957
#                         0.3           0.349398
#                         0.4           0.326291
#                         0.5           0.300000
# RandomForestClassifier  0.1           0.268551
#                         0.2           0.235714
#                         0.3           0.237785
#                         0.4           0.245902
#                         0.5           0.278647
# SVC                     0.1           0.262295
#                         0.2           0.258960
#                         0.3           0.227364
#                         0.4           0.238738
#                         0.5           0.246479
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.018883
#                         0.2           0.019711
#                         0.3           0.012195
#                         0.4           0.012572
#                         0.5           0.024240
# RandomForestClassifier  0.1           0.027332
#                         0.2           0.028529
#                         0.3           0.038868
#                         0.4           0.026804
#                         0.5           0.025522
# SVC                     0.1           0.030923
#                         0.2           0.036052
#                         0.3           0.024356
#                         0.4           0.026060
#                         0.5           0.017904
# Name: performance gap, dtype: float64

# %%
box_plot_retraining(summary, 'performance gap')

# %%
box_plot_retraining(summary, 'sample', hline=summary['sample'].mean())

# %%
summary = summary_retraining(path='../results/incremental/conf2')

# %%
summary
# Out:
#     dataset                   model proportion performance gap    sample
# 0       a9a                     SVC        0.5       -0.011485  0.690763
# 1       a9a    KNeighborsClassifier        0.5       -0.002772  0.690763
# 2       a9a  RandomForestClassifier        0.5       -0.004537  0.540809
# 3       a9a                     SVC        0.4        -0.01119  0.690802
# 4       a9a    KNeighborsClassifier        0.4       -0.000606  0.690802
# ..      ...                     ...        ...             ...       ...
# 550     w8a    KNeighborsClassifier        0.2        0.030229  0.219704
# 551     w8a  RandomForestClassifier        0.2        0.051007  0.139702
# 552     w8a                     SVC        0.1        0.052167  0.139702
# 553     w8a    KNeighborsClassifier        0.1        0.036218  0.209704
# 554     w8a  RandomForestClassifier        0.1        0.020357  0.134702
#
# [555 rows x 5 columns]

# %%
summary.groupby(['model', 'proportion'])['sample'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.432112
#                         0.2           0.427413
#                         0.3           0.418861
#                         0.4           0.412402
#                         0.5           0.389048
# RandomForestClassifier  0.1           0.284299
#                         0.2           0.274487
#                         0.3           0.277021
#                         0.4           0.273522
#                         0.5           0.283850
# SVC                     0.1           0.324210
#                         0.2           0.333720
#                         0.3           0.330415
#                         0.4           0.309782
#                         0.5           0.330540
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.008536
#                         0.2           0.004386
#                         0.3           0.003346
#                         0.4           0.007184
#                         0.5          -0.007278
# RandomForestClassifier  0.1           0.017706
#                         0.2           0.035526
#                         0.3           0.027676
#                         0.4           0.031001
#                         0.5           0.022420
# SVC                     0.1           0.021671
#                         0.2           0.019777
#                         0.3           0.011406
#                         0.4           0.020923
#                         0.5           0.019139
# Name: performance gap, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['sample'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.387960
#                         0.2           0.418476
#                         0.3           0.440476
#                         0.4           0.369006
#                         0.5           0.330692
# RandomForestClassifier  0.1           0.268551
#                         0.2           0.238026
#                         0.3           0.257545
#                         0.4           0.258844
#                         0.5           0.297101
# SVC                     0.1           0.261905
#                         0.2           0.278697
#                         0.3           0.264257
#                         0.4           0.258281
#                         0.5           0.254243
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.023580
#                         0.2           0.009396
#                         0.3           0.015472
#                         0.4           0.018312
#                         0.5           0.012870
# RandomForestClassifier  0.1           0.024292
#                         0.2           0.032544
#                         0.3           0.035563
#                         0.4           0.029715
#                         0.5           0.032715
# SVC                     0.1           0.017973
#                         0.2           0.022688
#                         0.3           0.019857
#                         0.4           0.023232
#                         0.5           0.024192
# Name: performance gap, dtype: float64

# %%
box_plot_retraining(summary, 'performance gap')

# %%
box_plot_retraining(summary, 'sample', hline=summary['sample'].mean())

# %%
summary = summary_retraining(path='../results/incremental/conf3')

# %%
summary
# Out:
#     dataset                   model proportion performance gap    sample
# 0       a9a                     SVC        0.5       -0.012913  0.690763
# 1       a9a    KNeighborsClassifier        0.5       -0.003861  0.690763
# 2       a9a  RandomForestClassifier        0.5       -0.000627  0.590794
# 3       a9a                     SVC        0.4       -0.006903  0.690802
# 4       a9a    KNeighborsClassifier        0.4       -0.001478  0.690802
# ..      ...                     ...        ...             ...       ...
# 550     w8a    KNeighborsClassifier        0.2        0.027334  0.299706
# 551     w8a  RandomForestClassifier        0.2        0.020865  0.179703
# 552     w8a                     SVC        0.1        0.035047  0.189703
# 553     w8a    KNeighborsClassifier        0.1        0.023937  0.299706
# 554     w8a  RandomForestClassifier        0.1        0.023489  0.134702
#
# [555 rows x 5 columns]

# %%
summary.groupby(['model', 'proportion'])['sample'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.469351
#                         0.2           0.464857
#                         0.3           0.433967
#                         0.4           0.464129
#                         0.5           0.455980
# RandomForestClassifier  0.1           0.316181
#                         0.2           0.310704
#                         0.3           0.292447
#                         0.4           0.308192
#                         0.5           0.302353
# SVC                     0.1           0.375573
#                         0.2           0.375014
#                         0.3           0.373153
#                         0.4           0.365472
#                         0.5           0.361408
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.004582
#                         0.2           0.007775
#                         0.3           0.005670
#                         0.4           0.006524
#                         0.5          -0.007030
# RandomForestClassifier  0.1           0.013961
#                         0.2           0.015751
#                         0.3           0.022042
#                         0.4           0.017470
#                         0.5           0.018121
# SVC                     0.1           0.013060
#                         0.2           0.017470
#                         0.3           0.014076
#                         0.4           0.015626
#                         0.5           0.017755
# Name: performance gap, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['sample'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.448795
#                         0.2           0.456740
#                         0.3           0.395893
#                         0.4           0.398357
#                         0.5           0.380509
# RandomForestClassifier  0.1           0.298056
#                         0.2           0.288623
#                         0.3           0.257545
#                         0.4           0.293737
#                         0.5           0.297101
# SVC                     0.1           0.281081
#                         0.2           0.317907
#                         0.3           0.315562
#                         0.4           0.294505
#                         0.5           0.303887
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.001191
#                         0.2           0.014148
#                         0.3           0.014175
#                         0.4           0.009757
#                         0.5           0.005062
# RandomForestClassifier  0.1           0.017860
#                         0.2           0.016821
#                         0.3           0.019710
#                         0.4           0.017157
#                         0.5           0.018890
# SVC                     0.1           0.013355
#                         0.2           0.018856
#                         0.3           0.024661
#                         0.4           0.020525
#                         0.5           0.017145
# Name: performance gap, dtype: float64

# %%
box_plot_retraining(summary, 'performance gap')

# %%
box_plot_retraining(summary, 'sample', hline=summary['sample'].mean())

# %%
summary = summary_retraining(path='../results/incremental/conf4')

# %%
summary
# Out:
#     dataset                   model proportion performance gap    sample
# 0       a9a                     SVC        0.5       -0.009407  0.690763
# 1       a9a    KNeighborsClassifier        0.5        -0.00336  0.690763
# 2       a9a  RandomForestClassifier        0.5       -0.001518  0.590794
# 3       a9a                     SVC        0.4        -0.00984  0.690802
# 4       a9a    KNeighborsClassifier        0.4       -0.007489  0.690802
# ..      ...                     ...        ...             ...       ...
# 550     w8a    KNeighborsClassifier        0.2        0.024261  0.359708
# 551     w8a  RandomForestClassifier        0.2        0.015463  0.179703
# 552     w8a                     SVC        0.1        0.024071  0.189703
# 553     w8a    KNeighborsClassifier        0.1        0.025394  0.299706
# 554     w8a  RandomForestClassifier        0.1        0.018953  0.184703
#
# [555 rows x 5 columns]

# %%
summary.groupby(['model', 'proportion'])['sample'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.503574
#                         0.2           0.524265
#                         0.3           0.499748
#                         0.4           0.526113
#                         0.5           0.505877
# RandomForestClassifier  0.1           0.340347
#                         0.2           0.345124
#                         0.3           0.342135
#                         0.4           0.339979
#                         0.5           0.353929
# SVC                     0.1           0.436628
#                         0.2           0.429495
#                         0.3           0.441795
#                         0.4           0.414123
#                         0.5           0.432038
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1          -0.000302
#                         0.2          -0.002096
#                         0.3          -0.002485
#                         0.4          -0.003372
#                         0.5          -0.005742
# RandomForestClassifier  0.1           0.021000
#                         0.2           0.014614
#                         0.3           0.020386
#                         0.4           0.020231
#                         0.5           0.017903
# SVC                     0.1           0.011780
#                         0.2           0.012524
#                         0.3           0.013049
#                         0.4           0.012356
#                         0.5           0.019779
# Name: performance gap, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['sample'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.479124
#                         0.2           0.478916
#                         0.3           0.459866
#                         0.4           0.479124
#                         0.5           0.455491
# RandomForestClassifier  0.1           0.305164
#                         0.2           0.315335
#                         0.3           0.321429
#                         0.4           0.298905
#                         0.5           0.299738
# SVC                     0.1           0.383312
#                         0.2           0.339593
#                         0.3           0.357143
#                         0.4           0.378382
#                         0.5           0.389189
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.000000
#                         0.2           0.000000
#                         0.3           0.000616
#                         0.4           0.000000
#                         0.5           0.003228
# RandomForestClassifier  0.1           0.021495
#                         0.2           0.015463
#                         0.3           0.020870
#                         0.4           0.019419
#                         0.5           0.019710
# SVC                     0.1           0.009271
#                         0.2           0.013946
#                         0.3           0.017376
#                         0.4           0.008739
#                         0.5           0.018990
# Name: performance gap, dtype: float64

# %%
box_plot_retraining(summary, 'performance gap')

# %%
box_plot_retraining(summary, 'sample', hline=summary['sample'].mean())

# %%
summary = summary_retraining(path='../results/incremental/conf5')

# %%
summary
# Out:
#     dataset                   model proportion performance gap    sample
# 0       a9a                     SVC        0.5       -0.010681  0.690763
# 1       a9a    KNeighborsClassifier        0.5       -0.006811  0.690763
# 2       a9a  RandomForestClassifier        0.5       -0.007009  0.665771
# 3       a9a                     SVC        0.4          -0.005  0.690802
# 4       a9a    KNeighborsClassifier        0.4       -0.001635  0.690802
# ..      ...                     ...        ...             ...       ...
# 550     w8a    KNeighborsClassifier        0.2        0.013318  0.399709
# 551     w8a  RandomForestClassifier        0.2        0.016859  0.199704
# 552     w8a                     SVC        0.1        0.020991  0.239705
# 553     w8a    KNeighborsClassifier        0.1        0.022837  0.389708
# 554     w8a  RandomForestClassifier        0.1        0.024785  0.189703
#
# [555 rows x 5 columns]

# %%
summary.groupby(['model', 'proportion'])['sample'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.558987
#                         0.2           0.561010
#                         0.3           0.557988
#                         0.4           0.572260
#                         0.5           0.559095
# RandomForestClassifier  0.1           0.395282
#                         0.2           0.400799
#                         0.3           0.396745
#                         0.4           0.409548
#                         0.5           0.415045
# SVC                     0.1           0.487135
#                         0.2           0.505110
#                         0.3           0.495717
#                         0.4           0.482596
#                         0.5           0.497940
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.000475
#                         0.2          -0.005702
#                         0.3           0.000627
#                         0.4          -0.002979
#                         0.5          -0.008000
# RandomForestClassifier  0.1           0.004921
#                         0.2           0.006105
#                         0.3           0.019454
#                         0.4           0.016303
#                         0.5           0.009523
# SVC                     0.1           0.010901
#                         0.2           0.002606
#                         0.3           0.005559
#                         0.4           0.011905
#                         0.5           0.010694
# Name: performance gap, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['sample'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.508048
#                         0.2           0.491803
#                         0.3           0.496703
#                         0.4           0.529730
#                         0.5           0.496703
# RandomForestClassifier  0.1           0.395604
#                         0.2           0.377049
#                         0.3           0.359161
#                         0.4           0.398788
#                         0.5           0.397678
# SVC                     0.1           0.388649
#                         0.2           0.458354
#                         0.3           0.459866
#                         0.4           0.440476
#                         0.5           0.428571
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.001231
#                         0.2           0.000000
#                         0.3           0.003495
#                         0.4           0.000000
#                         0.5           0.004623
# RandomForestClassifier  0.1           0.007835
#                         0.2           0.010199
#                         0.3           0.010555
#                         0.4           0.012364
#                         0.5           0.014489
# SVC                     0.1           0.012256
#                         0.2           0.009798
#                         0.3           0.004926
#                         0.4           0.007829
#                         0.5           0.010023
# Name: performance gap, dtype: float64

# %%
np.percentile(summary[summary['model'] == 'KNeighborsClassifier']['performance gap'].values, [10, 50, 90], axis=0)
# Out:
# array([-0.03166680330604515, 0.0007352157515321256, 0.035885348036569814],
#       dtype=object)

# %%
np.percentile(summary[summary['model'] == 'KNeighborsClassifier']['sample'].values, [25, 50, 75], axis=0)
# Out:
# array([0.4197090379155255, 0.4997691952608094, 0.7327586206896551],
#       dtype=object)

# %%
box_plot_retraining(summary, 'performance gap')

# %%
box_plot_retraining(summary, 'sample', hline=summary['sample'].mean())

# %%
summary = summary_retraining(path='../results/incremental/conf6')

# %%
summary
# Out:
#     dataset                   model proportion performance gap    sample
# 0       a9a                     SVC        0.5       -0.009575  0.690763
# 1       a9a    KNeighborsClassifier        0.5       -0.004112  0.690763
# 2       a9a  RandomForestClassifier        0.5       -0.009314  0.690763
# 3       a9a                     SVC        0.4       -0.010173  0.690802
# 4       a9a    KNeighborsClassifier        0.4       -0.006616  0.690802
# ..      ...                     ...        ...             ...       ...
# 550     w8a    KNeighborsClassifier        0.2        0.018937  0.399709
# 551     w8a  RandomForestClassifier        0.2        0.004329  0.279706
# 552     w8a                     SVC        0.1        0.012739  0.289706
# 553     w8a    KNeighborsClassifier        0.1        0.023171  0.389708
# 554     w8a  RandomForestClassifier        0.1        0.009019  0.279706
#
# [555 rows x 5 columns]

# %%
summary.groupby(['model', 'proportion'])['sample'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.604278
#                         0.2           0.593505
#                         0.3           0.594224
#                         0.4           0.607739
#                         0.5           0.572757
# RandomForestClassifier  0.1           0.442884
#                         0.2           0.457321
#                         0.3           0.464209
#                         0.4           0.479637
#                         0.5           0.475045
# SVC                     0.1           0.561220
#                         0.2           0.543132
#                         0.3           0.538984
#                         0.4           0.551473
#                         0.5           0.551355
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].mean()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.000690
#                         0.2          -0.004047
#                         0.3           0.000123
#                         0.4          -0.003453
#                         0.5          -0.011800
# RandomForestClassifier  0.1           0.002471
#                         0.2           0.006386
#                         0.3           0.012072
#                         0.4           0.005375
#                         0.5           0.000253
# SVC                     0.1           0.006657
#                         0.2           0.004773
#                         0.3           0.008919
#                         0.4           0.012585
#                         0.5           0.007019
# Name: performance gap, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['sample'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.583333
#                         0.2           0.535714
#                         0.3           0.551020
#                         0.4           0.556856
#                         0.5           0.499274
# RandomForestClassifier  0.1           0.443243
#                         0.2           0.496703
#                         0.3           0.482759
#                         0.4           0.496703
#                         0.5           0.479167
# SVC                     0.1           0.521739
#                         0.2           0.535714
#                         0.3           0.528571
#                         0.4           0.499393
#                         0.5           0.499544
# Name: sample, dtype: float64

# %%
summary.groupby(['model', 'proportion'])['performance gap'].median()
# Out:
# model                   proportion
# KNeighborsClassifier    0.1           0.000000
#                         0.2           0.000000
#                         0.3           0.008226
#                         0.4           0.000000
#                         0.5           0.000000
# RandomForestClassifier  0.1           0.004826
#                         0.2           0.009590
#                         0.3           0.009705
#                         0.4           0.006273
#                         0.5           0.007838
# SVC                     0.1           0.000000
#                         0.2           0.000000
#                         0.3           0.001276
#                         0.4           0.004914
#                         0.5           0.009271
# Name: performance gap, dtype: float64

# %%
box_plot_retraining(summary, 'performance gap')

# %%
box_plot_retraining(summary, 'sample', hline=summary['sample'].median())

# %%
summary = pd.concat([summary_retraining(path=f'../results/incremental/conf{i+1}', setting_col=True) for i in range(6)] , ignore_index=True)

# %%
df_plot = summary.groupby(['setting', 'model', 'proportion'])[['performance gap', 'sample']].mean().reset_index()

# %%
# Draw a pointplot to show pulse as a function of three categorical factors
for model in df_plot['model'].unique():
    sns_plot = sns.catplot(x="proportion", y="performance gap", hue="setting", #row='model',
                    capsize=.2, palette="husl", height=8, aspect=1.5,sharey=True,
                    kind="point", data=df_plot[df_plot['model'] == model], legend=True, legend_out=False)
    sns_plot.despine(left=True).set_axis_labels(f"{model}")

# %%
# Draw a pointplot to show pulse as a function of three categorical factors
for model in df_plot['model'].unique():
    sns_plot = sns.catplot(x="proportion", y="sample", hue="setting", #row='model',
                    capsize=.2, palette="husl", height=8, aspect=1.5,sharey=True,
                    kind="point", data=df_plot[df_plot['model'] == model], legend=True, legend_out=False)
    sns_plot.despine(left=True).set_axis_labels(f"{model}")
