# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from src.visualization.plots import *
from src.utils import *

# %%
df = summary_relative_error()

# %%
score_by_sampling(df, 'test_score_kdn')
# Out:
#           SVC  KNeighborsClassifier  RandomForestClassifier
# 0.1  0.063465              0.069901                0.070973
# 0.2  0.033062              0.044556                0.062465
# 0.3  0.025992              0.015492                0.034637
# 0.4  0.007059              0.015195                0.016901
# 0.5  0.002240              0.007575                0.004272
# 0.6 -0.002469             -0.009371                0.006404
# 0.7 -0.003265             -0.009886               -0.002182
# 0.8  0.002261             -0.006187               -0.012948
# 0.9 -0.000457             -0.005111               -0.000157

# %%
score_by_sampling(df, 'test_score_kdn_balanced')
# Out:
#           SVC  KNeighborsClassifier  RandomForestClassifier
# 0.1  0.065813              0.053907                0.099957
# 0.2  0.011144              0.019504                0.031529
# 0.3  0.000754              0.006106                0.023522
# 0.4  0.005083              0.004002                0.020823
# 0.5  0.002256              0.002176                0.008021
# 0.6 -0.005662             -0.000587               -0.007872
# 0.7  0.002342             -0.007980               -0.005720
# 0.8  0.003826             -0.007477               -0.012912
# 0.9  0.000846             -0.006368               -0.010402

# %%
score_by_sampling(df, 'test_score_dynamic_kdn')
# Out:
#           SVC  KNeighborsClassifier  RandomForestClassifier
# 0.1  0.124640              0.144101                0.142231
# 0.2  0.077290              0.084152                0.081403
# 0.3  0.040135              0.064800                0.049061
# 0.4  0.032442              0.040126                0.033063
# 0.5  0.026459              0.034950                0.020183
# 0.6  0.022263              0.017030                0.007443
# 0.7 -0.000334              0.012121                0.002879
# 0.8 -0.004320              0.011795               -0.004855
# 0.9 -0.004162              0.011621                0.000618

# %%
score_by_sampling(df, 'test_score_dynamic_kdn_balanced')
# Out:
#           SVC  KNeighborsClassifier  RandomForestClassifier
# 0.1  0.142867              0.134453                0.150069
# 0.2  0.060197              0.050573                0.088271
# 0.3  0.039273              0.027742                0.047880
# 0.4  0.018695              0.012975                0.012009
# 0.5  0.017342              0.010162                0.011199
# 0.6  0.000769              0.007363               -0.000165
# 0.7  0.007837             -0.007512               -0.000307
# 0.8  0.000095             -0.002138                0.001985
# 0.9 -0.001524             -0.013023               -0.002892

# %%
box_plot(df, 'test_score_kdn')

# %%
box_plot(df, 'test_score_kdn_balanced')

# %%
box_plot(df, 'test_score_dynamic_kdn')

# %%
box_plot(df, 'test_score_dynamic_kdn_balanced')
